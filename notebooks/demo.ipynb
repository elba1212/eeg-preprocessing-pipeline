# %% [markdown]
# # eeg-preprocessing-pipeline demo
#
# This notebook will demonstrate loading an EEG dataset, running the preprocessing pipeline, and reviewing quality-control outputs once the algorithms are implemented.
